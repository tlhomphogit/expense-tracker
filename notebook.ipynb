# %%
import argparse
import csv
import os

# class Items:
#     def __init__(self, items):
#         self.items = items

#     def __str__(self):
#         return f'{self.items}'

class Expenses:
    def __init__(self):
        self.expenses = []

    def read_from_file(self, filepath):
        if not os.path.exists(filepath):
            raise FileNotFoundError(f'Error! The file {filepath} was not found.')
        
        with open(filepath, mode='r') as file:
            expense_data = csv.DictReader(file)

            for row in expense_data:
                row['amount'] = float(row['amount'])
                self.expenses.append(row)
        # return Items(self.expenses)
    def calc_total_spend(self):
        # amounts = [s.get('amount') for s in self.expenses] or ...
        amounts = [s['amount'] for s in self.expenses]
        self.total =  round(sum(amounts), 2)
        return self.total

    def print_recorded_expenses(self):
        print('-' * 110)
        print(f'{" ":<39} {"PERSONAL EXPENSE TRACKER"}')
        print('-' * 110)
        print(f'{"Item Name":<28} {"Amount":<10} {"Category":<12} {"Description"}')
        print('-' * 110)
        for items in self.expenses:
            print(f'{items["item_name"]:<28} {items["amount"]:<10} {items["category"]:<12} {items["description"]}')
        print('-' * 110)
        print(f'{"TOTAL":<28} {self.calc_total_spend()}')
        print('-' * 110)


file = '/home/wethinkcode/Documents/WeThinkCode/expense-tracker/expenses.csv'
expenses = Expenses()
expenses.read_from_file(file)
# items = Items(expenses.read_from_file(file))
expenses.print_recorded_expenses()
# Out:
# --------------------------------------------------------------------------------------------------------------
#                                         PERSONAL EXPENSE TRACKER
# --------------------------------------------------------------------------------------------------------------
# Item Name                    Amount     Category     Description
# --------------------------------------------------------------------------------------------------------------
# Pink Lady Apples (1.5kg)     49.99      Fruit        Bag of crisp, sweet red apples.
# Rotisserie Chicken           119.99     Meat         Hot, roasted whole chicken with herb seasoning.
# Chuckles (125g)              64.99      Sweets       Malted puffs covered in milk chocolate.
# Ayrshire Milk (2L)           45.99      Dairy        Fresh full-cream milk in a plastic jug.
# Plain T-Shirt                159.0      Clothes      White cotton crew-neck shirt.
# Beef Lasagna (1kg)           179.99     Dinner       Ready-made pasta meal with mince and white sauce.
# Sparkling Water (500ml)      16.99      Drink        Lemon-flavoured fizzy water, sugar-free.
# Hass Avocados (4 pk)         69.99      Fruit        Net bag of four ripe avocados.
# Chicken Mayo Sandwich        54.99      Lunch        Triangular bread wedges with chicken filling.
# Wine Gums (400g)             42.99      Sweets       Chewy fruit-flavoured gum sweets.
# Reusable Shopper             12.0       Bag          Black fabric bag made from recycled plastic.
# Double Cream Yoghurt (1kg)   47.99      Dairy        Thick plain yoghurt in a tub.
# Sliced White Bread           18.99      Bakery       Soft loaf of white bread, pre-sliced.
# Free Range Eggs (18 pk)      109.99     Eggs         Large box of mixed-size free-range eggs.
# Salt & Pepper Chips (150g)   24.99      Chips        Crinkle-cut potato chips with black pepper seasoning.
# 100% Orange Juice (1.5L)     39.99      Drink        Pulp-free fruit juice in a plastic bottle.
# Greek Salad                  64.99      Salad        Bowl of lettuce, tomatoes, cucumber, olives, and feta.
# Rump Steak (2 pk)            189.99     Meat         Two thick cuts of matured beef steak.
# Ankle Socks (5 pk)           129.0      Clothes      Pack of five black cotton socks.
# Hand Wash (500ml)            39.99      Toiletries   Liquid soap with a lavender scent.
# --------------------------------------------------------------------------------------------------------------
# TOTAL                        1482.83
# --------------------------------------------------------------------------------------------------------------
